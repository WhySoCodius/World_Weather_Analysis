# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 729

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hovd
# Processing Record 2 of Set 1 | cherlak
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | flin flon
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | harper
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | esperance
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | ola
# Processing Record 15 of Set 1 | ilulissat
# Processing Record 16 of Set 1 | tarauaca
# Processing Record 17 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 1 | vardo
# Processing Record 19 of Set 1 | kayerkan
# Processing Record 20 of Set 1 | cedar city
# Processing Record 21 of Set 1 | muros
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | bethel
# Processing Record 28 of Set 1 | muzhi
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | sitka
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | pahalgam
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | lasa
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | fonte boa
# Processing Record 37 of Set 1 | murray bridge
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | ossora
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | port lincoln
# Processing Record 42 of Set 1 | saint-joseph
# Processing Record 43 of Set 1 | macomb
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | caraguatatuba
# Processing Record 48 of Set 1 | axim
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | kodiak
# Processing Record 1 of Set 2 | punta arenas
# Processing Record 2 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 2 | santa cruz de la palma
# Processing Record 4 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 2 | friesoythe
# Processing Record 6 of Set 2 | omboue
# Processing Record 7 of Set 2 | kaili
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | nelson bay
# Processing Record 10 of Set 2 | puerto leguizamo
# Processing Record 11 of Set 2 | merauke
# Processing Record 12 of Set 2 | opobo
# City not found. Skipping...
# Processing Record 13 of Set 2 | mahebourg
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | avera
# Processing Record 16 of Set 2 | formosa
# Processing Record 17 of Set 2 | trinidad
# Processing Record 18 of Set 2 | kahului
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | kapoeta
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | atar
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | tommot
# Processing Record 26 of Set 2 | touros
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | te anau
# Processing Record 29 of Set 2 | la ronge
# Processing Record 30 of Set 2 | santo antonio do ica
# Processing Record 31 of Set 2 | hamilton
# Processing Record 32 of Set 2 | bambous virieux
# Processing Record 33 of Set 2 | mitchell
# Processing Record 34 of Set 2 | slavsk
# Processing Record 35 of Set 2 | irtyshskiy
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | bredasdorp
# Processing Record 38 of Set 2 | namibe
# Processing Record 39 of Set 2 | loiza
# Processing Record 40 of Set 2 | hualmay
# Processing Record 41 of Set 2 | okhotsk
# Processing Record 42 of Set 2 | miyang
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | guabito
# Processing Record 47 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 2 | tuatapere
# Processing Record 49 of Set 2 | zhoucheng
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | tual
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | mehamn
# Processing Record 4 of Set 3 | hasaki
# Processing Record 5 of Set 3 | chaman
# Processing Record 6 of Set 3 | bluff
# Processing Record 7 of Set 3 | muisne
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | torbay
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | cabedelo
# Processing Record 14 of Set 3 | cherskiy
# Processing Record 15 of Set 3 | tallahassee
# Processing Record 16 of Set 3 | comodoro rivadavia
# Processing Record 17 of Set 3 | qaqortoq
# Processing Record 18 of Set 3 | necochea
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | tiznit
# Processing Record 23 of Set 3 | sabha
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | poum
# Processing Record 26 of Set 3 | bhayavadar
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 29 of Set 3 | muncar
# Processing Record 30 of Set 3 | avarua
# Processing Record 31 of Set 3 | cajati
# Processing Record 32 of Set 3 | shingu
# Processing Record 33 of Set 3 | sisimiut
# Processing Record 34 of Set 3 | atasu
# Processing Record 35 of Set 3 | prado
# Processing Record 36 of Set 3 | klaksvik
# Processing Record 37 of Set 3 | laguna
# Processing Record 38 of Set 3 | nyurba
# Processing Record 39 of Set 3 | vaini
# Processing Record 40 of Set 3 | duku
# Processing Record 41 of Set 3 | suntar
# Processing Record 42 of Set 3 | kaitangata
# Processing Record 43 of Set 3 | jacareacanga
# Processing Record 44 of Set 3 | fortuna
# Processing Record 45 of Set 3 | yulara
# Processing Record 46 of Set 3 | chuy
# Processing Record 47 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 3 | pangnirtung
# Processing Record 49 of Set 3 | gilbues
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | port elizabeth
# Processing Record 2 of Set 4 | bonga
# Processing Record 3 of Set 4 | egvekinot
# Processing Record 4 of Set 4 | yima
# Processing Record 5 of Set 4 | goderich
# Processing Record 6 of Set 4 | tando muhammad khan
# Processing Record 7 of Set 4 | san quintin
# Processing Record 8 of Set 4 | razole
# Processing Record 9 of Set 4 | kavieng
# Processing Record 10 of Set 4 | brooks
# Processing Record 11 of Set 4 | mount gambier
# Processing Record 12 of Set 4 | cape town
# Processing Record 13 of Set 4 | kousseri
# Processing Record 14 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 4 | salas
# Processing Record 16 of Set 4 | bonavista
# Processing Record 17 of Set 4 | boliqueime
# Processing Record 18 of Set 4 | butaritari
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | meulaboh
# Processing Record 21 of Set 4 | baruun-urt
# Processing Record 22 of Set 4 | ulaangom
# Processing Record 23 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 4 | verkhnevilyuysk
# Processing Record 25 of Set 4 | burnie
# Processing Record 26 of Set 4 | moerai
# Processing Record 27 of Set 4 | santa cruz
# Processing Record 28 of Set 4 | okitipupa
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | komsomolskiy
# Processing Record 31 of Set 4 | olafsvik
# Processing Record 32 of Set 4 | berlevag
# Processing Record 33 of Set 4 | cockburn town
# Processing Record 34 of Set 4 | tautira
# Processing Record 35 of Set 4 | ponta do sol
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | celestun
# Processing Record 38 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 4 | lazaro cardenas
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | geraldton
# Processing Record 42 of Set 4 | tokur
# Processing Record 43 of Set 4 | hofn
# Processing Record 44 of Set 4 | henties bay
# Processing Record 45 of Set 4 | kolosovka
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | barranca
# Processing Record 48 of Set 4 | ulaanbaatar
# Processing Record 49 of Set 4 | la mesa
# Processing Record 50 of Set 4 | tiksi
# Processing Record 1 of Set 5 | yuncheng
# Processing Record 2 of Set 5 | bengkulu
# Processing Record 3 of Set 5 | saint-augustin
# Processing Record 4 of Set 5 | lorengau
# Processing Record 5 of Set 5 | honiara
# Processing Record 6 of Set 5 | halifax
# Processing Record 7 of Set 5 | salvador
# Processing Record 8 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 5 | porto de moz
# Processing Record 10 of Set 5 | nouadhibou
# Processing Record 11 of Set 5 | sinnamary
# Processing Record 12 of Set 5 | katsuura
# Processing Record 13 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 5 | kapaa
# Processing Record 15 of Set 5 | kruisfontein
# Processing Record 16 of Set 5 | serenje
# Processing Record 17 of Set 5 | sorland
# Processing Record 18 of Set 5 | karauzyak
# City not found. Skipping...
# Processing Record 19 of Set 5 | kieta
# Processing Record 20 of Set 5 | filingue
# Processing Record 21 of Set 5 | opuwo
# Processing Record 22 of Set 5 | ponta delgada
# Processing Record 23 of Set 5 | coquimbo
# Processing Record 24 of Set 5 | new norfolk
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | victoria
# Processing Record 27 of Set 5 | hirara
# Processing Record 28 of Set 5 | potiskum
# Processing Record 29 of Set 5 | lagoa
# Processing Record 30 of Set 5 | dwarka
# Processing Record 31 of Set 5 | batemans bay
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | batsfjord
# Processing Record 34 of Set 5 | manzil tamim
# City not found. Skipping...
# Processing Record 35 of Set 5 | guerrero negro
# Processing Record 36 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 5 | ambilobe
# Processing Record 38 of Set 5 | kongolo
# Processing Record 39 of Set 5 | vanavara
# Processing Record 40 of Set 5 | mikuni
# Processing Record 41 of Set 5 | vao
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | souillac
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | rodrigues alves
# Processing Record 46 of Set 5 | grand gaube
# Processing Record 47 of Set 5 | atagay
# Processing Record 48 of Set 5 | labuan
# Processing Record 49 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 5 | tartagal
# Processing Record 1 of Set 6 | punta alta
# Processing Record 2 of Set 6 | weligama
# Processing Record 3 of Set 6 | rawson
# Processing Record 4 of Set 6 | stokmarknes
# Processing Record 5 of Set 6 | san joaquin
# Processing Record 6 of Set 6 | pevek
# Processing Record 7 of Set 6 | bundibugyo
# Processing Record 8 of Set 6 | beloha
# Processing Record 9 of Set 6 | goure
# Processing Record 10 of Set 6 | martinez
# Processing Record 11 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 6 | suclayin
# Processing Record 14 of Set 6 | smithers
# Processing Record 15 of Set 6 | rio cuarto
# Processing Record 16 of Set 6 | crotone
# Processing Record 17 of Set 6 | yichun
# Processing Record 18 of Set 6 | paamiut
# Processing Record 19 of Set 6 | kirkwall
# Processing Record 20 of Set 6 | sudak
# Processing Record 21 of Set 6 | baykit
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | san cristobal
# Processing Record 24 of Set 6 | nola
# Processing Record 25 of Set 6 | lebu
# Processing Record 26 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 27 of Set 6 | tandil
# Processing Record 28 of Set 6 | qasigiannguit
# Processing Record 29 of Set 6 | maragogi
# Processing Record 30 of Set 6 | yumen
# Processing Record 31 of Set 6 | conceicao do araguaia
# Processing Record 32 of Set 6 | mayo
# Processing Record 33 of Set 6 | palafrugell
# Processing Record 34 of Set 6 | roebourne
# Processing Record 35 of Set 6 | dunedin
# Processing Record 36 of Set 6 | sabzevar
# Processing Record 37 of Set 6 | mecca
# Processing Record 38 of Set 6 | ahipara
# Processing Record 39 of Set 6 | castro
# Processing Record 40 of Set 6 | upornaya
# Processing Record 41 of Set 6 | mosquera
# Processing Record 42 of Set 6 | rania
# Processing Record 43 of Set 6 | zaozerne
# Processing Record 44 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 6 | broken hill
# Processing Record 46 of Set 6 | waipawa
# Processing Record 47 of Set 6 | zabol
# Processing Record 48 of Set 6 | baft
# Processing Record 49 of Set 6 | nome
# Processing Record 50 of Set 6 | morgan city
# Processing Record 1 of Set 7 | arequipa
# Processing Record 2 of Set 7 | auki
# Processing Record 3 of Set 7 | belyy yar
# Processing Record 4 of Set 7 | kautokeino
# Processing Record 5 of Set 7 | nicoya
# Processing Record 6 of Set 7 | belogorsk
# Processing Record 7 of Set 7 | karata
# Processing Record 8 of Set 7 | jizan
# Processing Record 9 of Set 7 | talara
# Processing Record 10 of Set 7 | gushikawa
# Processing Record 11 of Set 7 | lagos
# Processing Record 12 of Set 7 | payo
# Processing Record 13 of Set 7 | la libertad
# Processing Record 14 of Set 7 | estelle
# Processing Record 15 of Set 7 | skegness
# Processing Record 16 of Set 7 | sioux lookout
# Processing Record 17 of Set 7 | karatau
# Processing Record 18 of Set 7 | lundamo
# Processing Record 19 of Set 7 | los llanos de aridane
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | ballina
# Processing Record 22 of Set 7 | vuktyl
# Processing Record 23 of Set 7 | karasburg
# Processing Record 24 of Set 7 | griffith
# Processing Record 25 of Set 7 | payakumbuh
# Processing Record 26 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | santa eulalia
# Processing Record 28 of Set 7 | phan thiet
# Processing Record 29 of Set 7 | scalea
# Processing Record 30 of Set 7 | luoyang
# Processing Record 31 of Set 7 | paralimni
# Processing Record 32 of Set 7 | talas
# Processing Record 33 of Set 7 | half moon bay
# Processing Record 34 of Set 7 | gbadolite
# Processing Record 35 of Set 7 | reinosa
# Processing Record 36 of Set 7 | larsnes
# Processing Record 37 of Set 7 | la solana
# Processing Record 38 of Set 7 | banka
# Processing Record 39 of Set 7 | sao joao da barra
# Processing Record 40 of Set 7 | dalnerechensk
# Processing Record 41 of Set 7 | lukovetskiy
# Processing Record 42 of Set 7 | zhigalovo
# Processing Record 43 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 44 of Set 7 | tasiilaq
# Processing Record 45 of Set 7 | thinadhoo
# Processing Record 46 of Set 7 | havre
# Processing Record 47 of Set 7 | mirabad
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | brzesko
# Processing Record 50 of Set 7 | hoquiam
# Processing Record 1 of Set 8 | yeppoon
# Processing Record 2 of Set 8 | lahan
# Processing Record 3 of Set 8 | iqaluit
# Processing Record 4 of Set 8 | atambua
# Processing Record 5 of Set 8 | saldanha
# Processing Record 6 of Set 8 | lagunas
# Processing Record 7 of Set 8 | bathsheba
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 8 | sibolga
# Processing Record 10 of Set 8 | pasighat
# Processing Record 11 of Set 8 | brae
# Processing Record 12 of Set 8 | chigorodo
# Processing Record 13 of Set 8 | ust-uda
# Processing Record 14 of Set 8 | rio gallegos
# Processing Record 15 of Set 8 | lumby
# Processing Record 16 of Set 8 | puerto escondido
# Processing Record 17 of Set 8 | moberly
# Processing Record 18 of Set 8 | alofi
# Processing Record 19 of Set 8 | narsaq
# Processing Record 20 of Set 8 | faanui
# Processing Record 21 of Set 8 | stolin
# Processing Record 22 of Set 8 | guliston
# Processing Record 23 of Set 8 | grindavik
# Processing Record 24 of Set 8 | guatire
# Processing Record 25 of Set 8 | ugoofaaru
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | gizo
# Processing Record 28 of Set 8 | soto la marina
# Processing Record 29 of Set 8 | pochutla
# Processing Record 30 of Set 8 | bima
# Processing Record 31 of Set 8 | moussoro
# Processing Record 32 of Set 8 | bud
# Processing Record 33 of Set 8 | kirakira
# Processing Record 34 of Set 8 | katobu
# Processing Record 35 of Set 8 | codrington
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | mount isa
# Processing Record 38 of Set 8 | altay
# Processing Record 39 of Set 8 | bara
# Processing Record 40 of Set 8 | saint-pierre
# Processing Record 41 of Set 8 | biak
# Processing Record 42 of Set 8 | yamada
# Processing Record 43 of Set 8 | padang
# Processing Record 44 of Set 8 | uwayl
# City not found. Skipping...
# Processing Record 45 of Set 8 | granadilla de abona
# Processing Record 46 of Set 8 | bella union
# Processing Record 47 of Set 8 | lakes entrance
# Processing Record 48 of Set 8 | shimoda
# Processing Record 49 of Set 8 | ipoh
# Processing Record 50 of Set 8 | orotina
# Processing Record 1 of Set 9 | jalu
# Processing Record 2 of Set 9 | nantucket
# Processing Record 3 of Set 9 | lapua
# Processing Record 4 of Set 9 | leningradskiy
# Processing Record 5 of Set 9 | ellisras
# Processing Record 6 of Set 9 | portland
# Processing Record 7 of Set 9 | broome
# Processing Record 8 of Set 9 | bemidji
# Processing Record 9 of Set 9 | mundwa
# Processing Record 10 of Set 9 | yukamenskoye
# Processing Record 11 of Set 9 | kungurtug
# Processing Record 12 of Set 9 | nabire
# Processing Record 13 of Set 9 | areosa
# Processing Record 14 of Set 9 | falkenberg
# Processing Record 15 of Set 9 | jequie
# Processing Record 16 of Set 9 | severnyy
# Processing Record 17 of Set 9 | manta
# Processing Record 18 of Set 9 | vitim
# Processing Record 19 of Set 9 | taltal
# Processing Record 20 of Set 9 | cotonou
# Processing Record 21 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 9 | athabasca
# Processing Record 23 of Set 9 | george
# Processing Record 24 of Set 9 | maun
# Processing Record 25 of Set 9 | eureka
# Processing Record 26 of Set 9 | arkadelphia
# Processing Record 27 of Set 9 | tucumcari
# Processing Record 28 of Set 9 | gimli
# Processing Record 29 of Set 9 | sao filipe
# Processing Record 30 of Set 9 | chongwe
# Processing Record 31 of Set 9 | bubaque
# Processing Record 32 of Set 9 | lucapa
# Processing Record 33 of Set 9 | balkanabat
# Processing Record 34 of Set 9 | barcelona
# Processing Record 35 of Set 9 | ancud
# Processing Record 36 of Set 9 | telimele
# Processing Record 37 of Set 9 | viedma
# Processing Record 38 of Set 9 | calderitas
# Processing Record 39 of Set 9 | sarakhs
# Processing Record 40 of Set 9 | novouzensk
# Processing Record 41 of Set 9 | antalaha
# Processing Record 42 of Set 9 | veraval
# Processing Record 43 of Set 9 | saint anthony
# Processing Record 44 of Set 9 | zhigansk
# Processing Record 45 of Set 9 | isangel
# Processing Record 46 of Set 9 | ixtapa
# Processing Record 47 of Set 9 | alta floresta
# Processing Record 48 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 49 of Set 9 | awjilah
# Processing Record 50 of Set 9 | enid
# Processing Record 1 of Set 10 | abay
# Processing Record 2 of Set 10 | ostrovnoy
# Processing Record 3 of Set 10 | miyako
# Processing Record 4 of Set 10 | sabancuy
# Processing Record 5 of Set 10 | srednekolymsk
# Processing Record 6 of Set 10 | beringovskiy
# Processing Record 7 of Set 10 | kenora
# Processing Record 8 of Set 10 | jacqueville
# Processing Record 9 of Set 10 | mgandu
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | raton
# Processing Record 12 of Set 10 | chapleau
# Processing Record 13 of Set 10 | kununurra
# Processing Record 14 of Set 10 | chimbote
# Processing Record 15 of Set 10 | asfi
# Processing Record 16 of Set 10 | sola
# Processing Record 17 of Set 10 | cilegon
# Processing Record 18 of Set 10 | kaeo
# Processing Record 19 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 20 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 21 of Set 10 | changli
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | gornopravdinsk
# Processing Record 24 of Set 10 | waingapu
# Processing Record 25 of Set 10 | saint-ambroise
# Processing Record 26 of Set 10 | kerman
# Processing Record 27 of Set 10 | ambon
# Processing Record 28 of Set 10 | luwuk
# Processing Record 29 of Set 10 | xingyi
# Processing Record 30 of Set 10 | tapa
# Processing Record 31 of Set 10 | indri
# Processing Record 32 of Set 10 | am timan
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | vanimo
# Processing Record 35 of Set 10 | tessalit
# Processing Record 36 of Set 10 | lesnyye polyany
# Processing Record 37 of Set 10 | airai
# Processing Record 38 of Set 10 | malkapur
# Processing Record 39 of Set 10 | davidson
# Processing Record 40 of Set 10 | doaba
# Processing Record 41 of Set 10 | presidencia roque saenz pena
# Processing Record 42 of Set 10 | novorudnyy
# Processing Record 43 of Set 10 | aksarka
# Processing Record 44 of Set 10 | saurimo
# Processing Record 45 of Set 10 | arman
# Processing Record 46 of Set 10 | alice springs
# Processing Record 47 of Set 10 | coihaique
# Processing Record 48 of Set 10 | chesma
# Processing Record 49 of Set 10 | saravena
# Processing Record 50 of Set 10 | dipolog
# Processing Record 1 of Set 11 | shirokiy
# Processing Record 2 of Set 11 | tombouctou
# Processing Record 3 of Set 11 | taft
# Processing Record 4 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 11 | singkang
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | araxa
# Processing Record 8 of Set 11 | yakymivka
# Processing Record 9 of Set 11 | abonnema
# Processing Record 10 of Set 11 | rio grande
# Processing Record 11 of Set 11 | pisco
# Processing Record 12 of Set 11 | jiaozuo
# Processing Record 13 of Set 11 | kota bahru
# Processing Record 14 of Set 11 | trincomalee
# Processing Record 15 of Set 11 | staraya poltavka
# Processing Record 16 of Set 11 | aldan
# Processing Record 17 of Set 11 | evanston
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | makat
# Processing Record 20 of Set 11 | dingle
# Processing Record 21 of Set 11 | lahad datu
# Processing Record 22 of Set 11 | margate
# Processing Record 23 of Set 11 | medea
# Processing Record 24 of Set 11 | lapeer
# Processing Record 25 of Set 11 | volterra
# Processing Record 26 of Set 11 | maniitsoq
# Processing Record 27 of Set 11 | dolinsk
# Processing Record 28 of Set 11 | faya
# Processing Record 29 of Set 11 | iwanai
# Processing Record 30 of Set 11 | melilla
# Processing Record 31 of Set 11 | cartagena
# Processing Record 32 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 11 | haverfordwest
# Processing Record 34 of Set 11 | baoshan
# Processing Record 35 of Set 11 | namatanai
# Processing Record 36 of Set 11 | tukrah
# Processing Record 37 of Set 11 | boca do acre
# Processing Record 38 of Set 11 | college
# Processing Record 39 of Set 11 | lompoc
# Processing Record 40 of Set 11 | touba
# Processing Record 41 of Set 11 | carndonagh
# Processing Record 42 of Set 11 | harrison
# Processing Record 43 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 44 of Set 11 | ust-kuyga
# Processing Record 45 of Set 11 | tsalka
# Processing Record 46 of Set 11 | bulaevo
# Processing Record 47 of Set 11 | bosansko grahovo
# Processing Record 48 of Set 11 | benoy
# Processing Record 49 of Set 11 | lafia
# Processing Record 50 of Set 11 | karpogory
# Processing Record 1 of Set 12 | evensk
# Processing Record 2 of Set 12 | tilichiki
# Processing Record 3 of Set 12 | dudinka
# Processing Record 4 of Set 12 | lerici
# Processing Record 5 of Set 12 | khani
# Processing Record 6 of Set 12 | karoi
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | sidi ali
# Processing Record 9 of Set 12 | bibiani
# Processing Record 10 of Set 12 | kurilsk
# Processing Record 11 of Set 12 | yekaterinovka
# Processing Record 12 of Set 12 | bafut
# Processing Record 13 of Set 12 | pskov
# Processing Record 14 of Set 12 | tasgaon
# Processing Record 15 of Set 12 | hede
# Processing Record 16 of Set 12 | belmonte
# Processing Record 17 of Set 12 | darhan
# Processing Record 18 of Set 12 | lamu
# Processing Record 19 of Set 12 | finote selam
# Processing Record 20 of Set 12 | ipil
# Processing Record 21 of Set 12 | alexandria
# Processing Record 22 of Set 12 | falmouth
# Processing Record 23 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 12 | talnakh
# Processing Record 25 of Set 12 | lata
# Processing Record 26 of Set 12 | port-cartier
# Processing Record 27 of Set 12 | potma
# City not found. Skipping...
# Processing Record 28 of Set 12 | andenes
# Processing Record 29 of Set 12 | urusha
# Processing Record 30 of Set 12 | zhezkazgan
# Processing Record 31 of Set 12 | hobyo
# Processing Record 32 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 34 of Set 12 | verkhnyaya sinyachikha
# Processing Record 35 of Set 12 | igarka
# Processing Record 36 of Set 12 | nosy varika
# Processing Record 37 of Set 12 | quatre cocos
# Processing Record 38 of Set 12 | anadyr
# Processing Record 39 of Set 12 | pacific grove
# Processing Record 40 of Set 12 | banda aceh
# Processing Record 41 of Set 12 | umm kaddadah
# Processing Record 42 of Set 12 | kikwit
# Processing Record 43 of Set 12 | creston
# Processing Record 44 of Set 12 | palmer
# Processing Record 45 of Set 12 | derzhavinsk
# Processing Record 46 of Set 12 | morondava
# Processing Record 47 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 48 of Set 12 | timmins
# Processing Record 49 of Set 12 | havre-saint-pierre
# Processing Record 50 of Set 12 | amot
# Processing Record 1 of Set 13 | newton stewart
# Processing Record 2 of Set 13 | vila velha
# Processing Record 3 of Set 13 | dhidhdhoo
# Processing Record 4 of Set 13 | high level
# Processing Record 5 of Set 13 | eastbourne
# Processing Record 6 of Set 13 | mahajanga
# Processing Record 7 of Set 13 | roblin
# Processing Record 8 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 9 of Set 13 | itoman
# Processing Record 10 of Set 13 | reconquista
# Processing Record 11 of Set 13 | abu samrah
# Processing Record 12 of Set 13 | carutapera
# Processing Record 13 of Set 13 | polessk
# Processing Record 14 of Set 13 | remedios
# Processing Record 15 of Set 13 | kalanaur
# Processing Record 16 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 17 of Set 13 | raudeberg
# Processing Record 18 of Set 13 | svetlyy
# Processing Record 19 of Set 13 | dandong
# Processing Record 20 of Set 13 | husavik
# Processing Record 21 of Set 13 | orillia
# Processing Record 22 of Set 13 | palembang
# Processing Record 23 of Set 13 | whitehorse
# Processing Record 24 of Set 13 | changji
# Processing Record 25 of Set 13 | homer
# Processing Record 26 of Set 13 | yalchiki
# City not found. Skipping...
# Processing Record 27 of Set 13 | leh
# Processing Record 28 of Set 13 | ponnani
# Processing Record 29 of Set 13 | hokitika
# Processing Record 30 of Set 13 | barahona
# Processing Record 31 of Set 13 | gebre guracha
# Processing Record 32 of Set 13 | adiake
# Processing Record 33 of Set 13 | woodstock
# Processing Record 34 of Set 13 | aloleng
# Processing Record 35 of Set 13 | shahrud
# Processing Record 36 of Set 13 | aksehir
# Processing Record 37 of Set 13 | morehead
# Processing Record 38 of Set 13 | muchkapskiy
# Processing Record 39 of Set 13 | pundaguitan
# Processing Record 40 of Set 13 | birao
# Processing Record 41 of Set 13 | port huron
# Processing Record 42 of Set 13 | igrim
# Processing Record 43 of Set 13 | bahadurgarh
# Processing Record 44 of Set 13 | nizwa
# Processing Record 45 of Set 13 | hambantota
# Processing Record 46 of Set 13 | lincoln
# Processing Record 47 of Set 13 | berbera
# Processing Record 48 of Set 13 | agua dulce
# Processing Record 49 of Set 13 | esik
# Processing Record 50 of Set 13 | kyzyl-mazhalyk
# Processing Record 1 of Set 14 | barcelos
# Processing Record 2 of Set 14 | aanekoski
# Processing Record 3 of Set 14 | kathu
# Processing Record 4 of Set 14 | amursk
# Processing Record 5 of Set 14 | kisangani
# Processing Record 6 of Set 14 | cap malheureux
# Processing Record 7 of Set 14 | karpathos
# Processing Record 8 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 9 of Set 14 | tres arroyos
# Processing Record 10 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 14 | kurumkan
# Processing Record 12 of Set 14 | fort nelson
# Processing Record 13 of Set 14 | sakakah
# Processing Record 14 of Set 14 | ribeira brava
# Processing Record 15 of Set 14 | samarai
# Processing Record 16 of Set 14 | constitucion
# Processing Record 17 of Set 14 | malegaon
# Processing Record 18 of Set 14 | pontes e lacerda
# Processing Record 19 of Set 14 | chernyshevskiy
# Processing Record 20 of Set 14 | sakaiminato
# Processing Record 21 of Set 14 | walvis bay
# Processing Record 22 of Set 14 | palana
# Processing Record 23 of Set 14 | road town
# Processing Record 24 of Set 14 | konevo
# Processing Record 25 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 26 of Set 14 | jambi
# Processing Record 27 of Set 14 | tongliao
# Processing Record 28 of Set 14 | oriximina
# Processing Record 29 of Set 14 | mongar
# Processing Record 30 of Set 14 | le port
# Processing Record 31 of Set 14 | tshikapa
# Processing Record 32 of Set 14 | hadrut
# Processing Record 33 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 14 | dasoguz
# Processing Record 35 of Set 14 | huarmey
# Processing Record 36 of Set 14 | uk
# City not found. Skipping...
# Processing Record 37 of Set 14 | rorvik
# Processing Record 38 of Set 14 | lodja
# Processing Record 39 of Set 14 | bodden town
# Processing Record 40 of Set 14 | novikovo
# Processing Record 41 of Set 14 | abu kamal
# Processing Record 42 of Set 14 | ituporanga
# Processing Record 43 of Set 14 | morros
# Processing Record 44 of Set 14 | wyandotte
# Processing Record 45 of Set 14 | arlit
# Processing Record 46 of Set 14 | yuanping
# Processing Record 47 of Set 14 | pitimbu
# Processing Record 48 of Set 14 | tamandare
# Processing Record 49 of Set 14 | nizhnevartovsk
# Processing Record 50 of Set 14 | chicama
# Processing Record 1 of Set 15 | calatrava
# Processing Record 2 of Set 15 | dom pedrito
# Processing Record 3 of Set 15 | amga
# Processing Record 4 of Set 15 | vila franca do campo
# Processing Record 5 of Set 15 | manggar
# Processing Record 6 of Set 15 | alyangula
# Processing Record 7 of Set 15 | palauig
# Processing Record 8 of Set 15 | mingguang
# Processing Record 9 of Set 15 | gazojak
# Processing Record 10 of Set 15 | maxixe
# Processing Record 11 of Set 15 | akdepe
# Processing Record 12 of Set 15 | shakawe
# Processing Record 13 of Set 15 | crato
# Processing Record 14 of Set 15 | muskogee
# Processing Record 15 of Set 15 | umm lajj
# Processing Record 16 of Set 15 | xuanwu
# Processing Record 17 of Set 15 | xiamen
# Processing Record 18 of Set 15 | cap-aux-meules
# Processing Record 19 of Set 15 | pedernales
# Processing Record 20 of Set 15 | vestmanna
# Processing Record 21 of Set 15 | prince rupert
# Processing Record 22 of Set 15 | bagdarin
# Processing Record 23 of Set 15 | carbonia
# Processing Record 24 of Set 15 | amposta
# Processing Record 25 of Set 15 | fort-shevchenko
# Processing Record 26 of Set 15 | ritchie
# Processing Record 27 of Set 15 | aboisso
# Processing Record 28 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 15 | port moresby
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Hovd      MN  48.0056   91.6419     66.04        30         100
# 1         Cherlak      RU  54.1550   74.8055     57.36        80          66
# 2          Hobart      AU -42.8794  147.3294     43.27        94          64
# 3     Tuktoyaktuk      CA  69.4541 -133.0374     51.80        58          75
# 4         Rikitea      PF -23.1203 -134.9692     72.54        66          13
# 5       Flin Flon      CA  54.7682 -101.8650     60.64        72         100
# 6   Mar Del Plata      AR -38.0023  -57.5575     53.10        77         100
# 7  Ribeira Grande      PT  38.5167  -28.7000     70.20        78          20
# 8          Harper      LR   4.3750   -7.7169     76.44        87         100
# 9    Puerto Ayora      EC  -0.7393  -90.3518     76.96        94          75
#
#    Wind Speed Current Description
# 0        7.23     overcast clouds
# 1        9.80       broken clouds
# 2       11.50       broken clouds
# 3       11.50       broken clouds
# 4        4.85          few clouds
# 5       11.50     overcast clouds
# 6        5.75     overcast clouds
# 7       18.41          few clouds
# 8       10.29     overcast clouds
# 9        8.01       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
